# %%
import pandas as pd 
import matplotlib.pyplot as plt

# -- player2 --
df2_1 = pd.read_csv("output/database_for_plot_2_42.csv")
df2_2 = pd.read_csv("output/database_for_plot_2_1000.csv")
df2_3 = pd.read_csv("output/database_for_plot_2_10000.csv")
# -- player3 --
df3_1 = pd.read_csv("output/database_for_plot_3_42.csv")
df3_2 = pd.read_csv("output/database_for_plot_3_1000.csv")
df3_3 = pd.read_csv("output/database_for_plot_3_10000.csv")
# -- player4 --
df4_1 = pd.read_csv("output/database_for_plot_4_42.csv")
df4_2 = pd.read_csv("output/database_for_plot_4_1000.csv")
df4_3 = pd.read_csv("output/database_for_plot_4_10000.csv")

# -- player5 --
df5_1 = pd.read_csv("output/database_for_plot_5_42.csv")
df5_2 = pd.read_csv("output/database_for_plot_5_1000.csv")
df5_3 = pd.read_csv("output/database_for_plot_5_10000.csv")


df = pd.concat([df2_1, df2_2, df2_3, df3_1, df3_2, df3_3, df4_1, df4_2, df4_3, df5_1, df5_2, df5_3], axis=1, join='outer')

df = df.loc[:,~df.columns.duplicated()]
df = df.set_index('iteration')
df["exploitability_rate_2_mean"] = df[["exploitability_rate_2_42", "exploitability_rate_2_1000", "exploitability_rate_2_10000"]].mean(axis=1)
df["exploitability_rate_3_mean"] = df[["exploitability_rate_3_42", "exploitability_rate_3_1000", "exploitability_rate_3_10000"]].mean(axis=1)
df["exploitability_rate_4_mean"] = df[["exploitability_rate_4_42", "exploitability_rate_4_1000", "exploitability_rate_4_10000"]].mean(axis=1)
df["exploitability_rate_5_mean"] = df[["exploitability_rate_5_42", "exploitability_rate_5_1000", "exploitability_rate_5_10000"]].mean(axis=1)

df.tail()
# Out:
#            exploitability_rate_2_42  exploitability_rate_2_1000  \
# iteration
# 100000                     0.228837                    0.228218
# 177827                     0.094043                    0.119848
# 316227                     0.043607                    0.042607
# 562341                     0.022852                    0.026800
# 1000000                    0.017673                    0.015463
#
#            exploitability_rate_2_10000  exploitability_rate_3_42  \
# iteration
# 100000                        0.171822                  0.163752
# 177827                        0.086636                  0.095272
# 316227                        0.036880                  0.032970
# 562341                        0.028789                  0.025199
# 1000000                       0.024936                  0.014683
#
#            exploitability_rate_3_1000  exploitability_rate_3_10000  \
# iteration
# 100000                       0.143976                     0.161577
# 177827                       0.074294                     0.083913
# 316227                       0.030419                     0.039214
# 562341                       0.025644                     0.023559
# 1000000                      0.017008                     0.019646
#
#            exploitability_rate_4_42  exploitability_rate_4_1000  \
# iteration
# 100000                     0.171689                    0.106144
# 177827                     0.094686                    0.062400
# 316227                     0.077098                    0.042495
# 562341                     0.068865                    0.020311
# 1000000                    0.066399                    0.016297
#
#            exploitability_rate_4_10000  exploitability_rate_5_42  \
# iteration
# 100000                        0.117847                  0.063408
# 177827                        0.069163                  0.031632
# 316227                        0.032448                  0.028543
# 562341                        0.022042                  0.020815
# 1000000                       0.018495                  0.014315
#
#            exploitability_rate_5_1000  exploitability_rate_5_10000  \
# iteration
# 100000                       0.159404                     0.069371
# 177827                       0.079875                     0.039885
# 316227                       0.070907                     0.026085
# 562341                       0.056254                     0.018528
# 1000000                      0.047172                     0.016926
#
#            exploitability_rate_2_mean  exploitability_rate_3_mean  \
# iteration
# 100000                       0.209625                    0.156435
# 177827                       0.100176                    0.084493
# 316227                       0.041031                    0.034201
# 562341                       0.026147                    0.024801
# 1000000                      0.019357                    0.017112
#
#            exploitability_rate_4_mean  exploitability_rate_5_mean
# iteration
# 100000                       0.131893                    0.097394
# 177827                       0.075416                    0.050464
# 316227                       0.050680                    0.041845
# 562341                       0.037073                    0.031866
# 1000000                      0.033730                    0.026138

# %%
plt.rcParams["font.size"] = 30
plt.figure(figsize=(24,12))
plt.plot(df.index, df.exploitability_rate_2_mean, label="2-Kuhn exploit" , lw=5)
plt.plot(df.index, df.exploitability_rate_3_mean, label="3-Kuhn exploit", lw=5)
plt.plot(df.index, df.exploitability_rate_4_mean, label="4-Kuhn exploit" , lw=5)
plt.plot(df.index, df.exploitability_rate_5_mean, label="5-Kuhn exploit", lw=5)

plt.xscale('log')
plt.yscale('log')
plt.xlabel('iteration')
plt.ylabel('exploitability rate')
plt.legend()
plt.grid()
plt.xlim(10)
plt.ylim(0.001,10)
plt.savefig("./png/kuhn_poker_nfsp.png")
