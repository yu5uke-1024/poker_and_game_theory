# %%
import pandas as pd 
import matplotlib.pyplot as plt

df1 = pd.read_csv("output/database_for_plot_outcome_sampling_MCCFR.csv")
df2 = pd.read_csv("output/database_for_plot_NFSP.csv")
df3 = pd.read_csv("output/database_for_plot_FSP.csv")


df = pd.concat([df1, df2, df3], axis=1, join='outer')

df = df.loc[:,~df.columns.duplicated()]
df = df.set_index('iteration')

df
# Out:
#            exploitability_outcome_sampling_MCCFR  exploitability_NFSP  \
# iteration
# 1                                       4.605093             4.747222
# 3                                       4.491204             4.747222
# 5                                       4.585648             4.747222
# 10                                      5.101927             4.747222
# 17                                      5.180281             4.747222
# 31                                      5.049337             4.747222
# 56                                      5.037292             4.850915
# 100                                     4.899920             5.030215
# 177                                     4.693863             4.966920
# 316                                     5.296369             4.924831
# 562                                     5.266661             4.917365
# 1000                                    4.122198             4.546719
# 1778                                    3.618972             4.311733
# 3162                                    2.704723             4.347649
# 5623                                    2.247472             4.228902
# 10000                                   1.668493             3.429904
# 17782                                   1.648780             2.408971
# 31622                                   1.418147             1.762166
# 56234                                   1.103849             1.380454
# 100000                                  1.015065             1.125699
# 177827                                  0.688599             0.980789
# 316227                                  0.572048             0.978314
# 562341                                  0.492901             0.967928
# 1000000                                 0.414797             0.817736
#
#            exploitability_FSP
# iteration
# 1                    4.782099
# 3                    4.929167
# 5                    4.731898
# 10                   4.754524
# 17                   5.075273
# 31                   4.975002
# 56                   4.913078
# 100                  5.649210
# 177                  5.755646
# 316                  5.469959
# 562                  5.582955
# 1000                 5.342069
# 1778                 5.224848
# 3162                 3.934758
# 5623                 2.637076
# 10000                1.865261
# 17782                1.499095
# 31622                1.092876
# 56234                1.002202
# 100000               0.865974
# 177827               0.733751
# 316227               0.572036
# 562341               0.520514
# 1000000              0.477399

# %%
plt.rcParams["font.size"] = 30
plt.figure(figsize=(24,12))

plt.plot(df.index, df.exploitability_FSP, label="FSP" , lw=5, color="dodgerblue")
plt.plot(df.index, df.exploitability_NFSP, label="NFSP", lw=5, color="magenta")
plt.plot(df.index, df.exploitability_outcome_sampling_MCCFR	, label="MCCFR" , lw=5, color="limegreen")

plt.xscale('log')
plt.yscale('log')
plt.xlabel('iteration')
plt.ylabel('exploitability')
plt.legend(loc='lower left')
plt.grid()

plt.xlim(10)
plt.ylim(0.1,10)
#plt.savefig("./png/leduc_poker_nfsp.png")
# Out:
# (0.1, 10)
