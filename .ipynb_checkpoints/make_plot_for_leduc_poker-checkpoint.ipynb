# %%
import pandas as pd 
import matplotlib.pyplot as plt


df1 = pd.read_csv("output/database_for_plot_outcome_sampling_MCCFR.csv")
df2 = pd.read_csv("output/database_for_plot_outcome_sampling_MCCFR.csv")
df3 = pd.read_csv("output/database_for_plot_outcome_sampling_MCCFR.csv")



df = pd.concat([df2_1, df2_2, df2_3], axis=1, join='outer')

df = df.loc[:,~df.columns.duplicated()]
df = df.set_index('iteration')

df.tail()
# Out:
# -------------------------------------------------------------
# FileNotFoundError           Traceback (most recent call last)
# <ipython-input-2-2b7d01f37d23> in <module>
#       3
#       4
# ----> 5 df1 = pd.read_csv("output/database_for_plot_outcome_sampling_MCCFR.csv")
#       6 df2 = pd.read_csv("output/database_for_plot_outcome_sampling_MCCFR.csv")
#       7 df3 = pd.read_csv("output/database_for_plot_outcome_sampling_MCCFR.csv")
#
# ...

# %%
plt.rcParams["font.size"] = 30
plt.figure(figsize=(24,12))
plt.plot(df.index, df.exploitability_rate_2_mean, label="2-Kuhn exploit" , lw=5)
plt.plot(df.index, df.exploitability_rate_3_mean, label="3-Kuhn exploit", lw=5)
plt.plot(df.index, df.exploitability_rate_4_mean, label="4-Kuhn exploit" , lw=5)
plt.plot(df.index, df.exploitability_rate_5_mean, label="5-Kuhn exploit", lw=5)

plt.xscale('log')
plt.yscale('log')
plt.xlabel('iteration')
plt.ylabel('exploitability rate')
plt.legend()
plt.grid()
plt.xlim(10)
plt.ylim(0.001,10)
plt.savefig("./png/kuhn_poker_nfsp.png")
# Out:
# -------------------------------------------------------------
# NameError                   Traceback (most recent call last)
# <ipython-input-3-a04de25b3816> in <module>
#       1 plt.rcParams["font.size"] = 30
#       2 plt.figure(figsize=(24,12))
# ----> 3 plt.plot(df.index, df.exploitability_rate_2_mean, label="2-Kuhn exploit" , lw=5)
#       4 plt.plot(df.index, df.exploitability_rate_3_mean, label="3-Kuhn exploit", lw=5)
#       5 plt.plot(df.index, df.exploitability_rate_4_mean, label="4-Kuhn exploit" , lw=5)
#
# NameError: name 'df' is not defined
