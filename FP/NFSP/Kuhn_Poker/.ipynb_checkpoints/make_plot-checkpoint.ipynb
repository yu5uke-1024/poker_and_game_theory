# %%
import pandas as pd 
import matplotlib.pyplot as plt

# -- player2 --
df2_1 = pd.read_csv("output/database_for_plot_2_42.csv")
df2_2 = pd.read_csv("output/database_for_plot_2_1000.csv")
df2_3 = pd.read_csv("output/database_for_plot_2_10000.csv")
# -- player3 --
df3_1 = pd.read_csv("output/database_for_plot_3_1000.csv")
df3_2 = pd.read_csv("output/database_for_plot_3_1000.csv")
df3_3 = pd.read_csv("output/database_for_plot_3_1000.csv")
# -- player4 --
df4_1 = pd.read_csv("output/database_for_plot_4_1000.csv")
df4_2 = pd.read_csv("output/database_for_plot_4_1000.csv")
df4_3 = pd.read_csv("output/database_for_plot_4_1000.csv")


df = pd.concat([df2_1, df2_2, df2_3, df3_1, df3_2, df3_3, df4_1, df4_2, df4_3], axis=1, join='outer')
df = df.loc[:,~df.columns.duplicated()]
df = df.set_index('iteration')
df["exploitability_rate_2_mean"] = df[["exploitability_rate_2_42", "exploitability_rate_2_1000", "exploitability_rate_2_10000"]].mean(axis=1)
#df["exploitability_rate_3_mean"] = df[["exploitability_rate_3_42", "exploitability_rate_3_1000", "exploitability_rate_3_10000"]].mean(axis=1)
#df["exploitability_rate_4_mean"] = df[["exploitability_rate_4_42", "exploitability_rate_4_1000", "exploitability_rate_4_10000"]].mean(axis=1)
#df["exploitability_rate_5_mean"] = df[["exploitability_rate_5_42", "exploitability_rate_5_1000", "exploitability_rate_5_10000"]].mean(axis=1)

df.tail()
# Out:
#            exploitability_rate_2_42  exploitability_rate_2_1000  \
# iteration
# 100000                     0.228837                    0.228218
# 177827                     0.094043                    0.119848
# 316227                     0.043607                    0.042607
# 562341                     0.022852                    0.026800
# 1000000                    0.017673                    0.015463
#
#            exploitability_rate_2_10000  exploitability_rate_3_1000  \
# iteration
# 100000                        0.171822                    0.143976
# 177827                        0.086636                    0.074294
# 316227                        0.036880                    0.030419
# 562341                        0.028789                    0.025644
# 1000000                       0.024936                    0.017008
#
#            exploitability_rate_4_1000  exploitability_rate_2_mean
# iteration
# 100000                            NaN                    0.209625
# 177827                            NaN                    0.100176
# 316227                            NaN                    0.041031
# 562341                            NaN                    0.026147
# 1000000                           NaN                    0.019357

# %%
plt.rcParams["font.size"] = 20
plt.figure(figsize=(24,12))
plt.plot(df.index, df.exploitability_rate_2_1000, label="2-Kuhn exploit")
plt.plot(df.index, df.exploitability_rate_3_1000, label="3-Kuhn exploit")
plt.plot(df.index, df.exploitability_rate_4_1000, label="4-Kuhn exploit")

plt.xscale('log')
plt.yscale('log')
plt.xlabel('iteration')
plt.ylabel('exploitability rate')
plt.legend()
plt.grid()
plt.xlim(10)
plt.ylim(0.001,10)
# Out:
# (0.001, 10)
